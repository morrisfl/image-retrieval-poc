# %%
from annoy import AnnoyIndex
from torchvision import transforms

from src.data import Paris6kDataset
from src.models import DINOv2Model
from src.utils import get_indexes, visualize_retrieval_results

# %%
# Model
model = DINOv2Model(model_name="dinov2_vits14")

# Transform
transform = transforms.Compose([
        transforms.Resize(256, interpolation=transforms.InterpolationMode.BICUBIC),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# Dataset
dataset = Paris6kDataset(root="../../dataset/paris6k", transform=transform)
query_dict = dataset.query_data
gallery_images = dataset.gallery_data

# Stored embeddings
embeddings = AnnoyIndex(384, "angular")
embeddings.load("../../embeddings/index25_dinov2_vits14_paris6k.ann")
# Out:
# Using cache found in /Users/morrisflorek/.cache/torch/hub/facebookresearch_dinov2_main
# xFormers not available
# xFormers not available
# True

# %%
query_label = "eiffel"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "defense"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "invalides"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "louvre"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "moulinrouge"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "museedorsay"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "notredame"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "pantheon"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "pompidou"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "sacrecoeur"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)

# %%
query_label = "triomphe"
query_img_path = query_dict[query_label][0]

indexes = get_indexes(model=model, img_path=query_img_path, embeddings=embeddings, top_k=6, transform=transform)

visualize_retrieval_results(query_label=query_label, img_path=query_img_path, gallery_img=gallery_images, indexes=indexes)
